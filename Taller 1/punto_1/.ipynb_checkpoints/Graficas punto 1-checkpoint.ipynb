# %%
import numpy as np 
import matplotlib.pyplot as plt
import scipy as sp
# %matplotlib inline

# %% [markdown]
# # Primera derivada

# %%
d1 = np.loadtxt('d1_2do.dat', unpack = True)
d2 = np.loadtxt('d1_4to.dat', unpack = True)

plt.loglog(d1[0],d1[1],"r.",label="$2^{do}$ orden")
plt.loglog(d2[0],d2[1],"b.",label="$4^{to}$ orden")

plt.grid(True)
plt.xlabel("$\\Delta.x$")
plt.ylabel("$L_{2}$")
plt.title("primera derivada")
plt.legend()

# %% [markdown]
# # Segunda derivada

# %%
d3 = np.loadtxt('d2_4to.dat', unpack = True)
d4 = np.loadtxt('d2_6to.dat', unpack = True)

plt.loglog(d3[0],d3[1],"r.",label="$2^{do}$ orden")
plt.loglog(d4[0],d4[1],"b.",label="$4^{to}$ orden")

plt.grid(True)
plt.xlabel("$\\Delta.x$")
plt.ylabel("$L_{2}$")
plt.title("Segunda derivada")
plt.legend()

# %% [markdown]
# # Esquemas compactos
#
# ## primera derivada

# %%
c1 = np.loadtxt('c1.dat', unpack = True)

plt.loglog(c1[0],c1[1],"r.",label="Compacto")

plt.grid(True)
plt.xlabel("$\\Delta.x$")
plt.ylabel("$L_{2}$")
plt.title("Segunda derivada")
plt.legend()

# %%
# %ls
# Out:
# Graficas punto 1.ipynb  compacto1.f90           d2_4to.dat
# a.out*                  compato2.f90            d2_6to.dat
# a.out.dSYM/             d1_2do.dat              derivative1.f90
# c1.dat                  d1_4to.dat              derivative2.f90
